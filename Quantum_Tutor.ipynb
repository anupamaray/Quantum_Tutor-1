# %%
# !git clone https://github.com/i-am-bee/beeai-framework.git
# %cd beeai-framework
# Out:
# Cloning into 'beeai-framework'...
# remote: Enumerating objects: 13643, done.
# remote: Counting objects: 100% (1708/1708), done.
# remote: Compressing objects: 100% (1114/1114), done.
# remote: Total 13643 (delta 1086), reused 737 (delta 586), pack-reused 11935 (from 4)
# Receiving objects: 100% (13643/13643), 7.97 MiB | 7.93 MiB/s, done.
# Resolving deltas: 100% (8483/8483), done.
# Updating files: 100% (696/696), done.
# /content/drive/MyDrive/quantum_tutor_project/beeai-framework-py-starter/beeai-framework

# %%
# !pip install fastapi==0.95.2 httpx==0.24.0 pydantic==1.10.7 uvicorn==0.23.1 requests==2.31.0 python-dotenv==1.0.0 click==8.1.3 aiohttp==3.8.4 PyYAML==6.0 pytest==7.4.0 pytest-asyncio==0.20.3
# Out:
# Collecting fastapi==0.95.2
#   Using cached fastapi-0.95.2-py3-none-any.whl.metadata (24 kB)
# Collecting httpx==0.24.0
#   Using cached httpx-0.24.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting pydantic==1.10.7
#   Using cached pydantic-1.10.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (145 kB)
# Collecting uvicorn==0.23.1
#   Using cached uvicorn-0.23.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting requests==2.31.0
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dotenv==1.0.0 in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Collecting click==8.1.3
#   Using cached click-8.1.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: aiohttp==3.8.4 in /usr/local/lib/python3.11/dist-packages (3.8.4)
# Requirement already satisfied: PyYAML==6.0 in /usr/local/lib/python3.11/dist-packages (6.0)
# Requirement already satisfied: pytest==7.4.0 in /usr/local/lib/python3.11/dist-packages (7.4.0)
# Requirement already satisfied: pytest-asyncio==0.20.3 in /usr/local/lib/python3.11/dist-packages (0.20.3)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi==0.95.2)
#   Using cached starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0) (2025.4.26)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx==0.24.0)
#   Using cached httpcore-0.17.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx==0.24.0) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from pydantic==1.10.7) (4.13.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn==0.23.1) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests==2.31.0) (2.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.8.4) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.8.4) (6.4.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.8.4) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.8.4) (1.20.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.8.4) (1.6.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp==3.8.4) (1.3.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.0) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.0) (24.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.0) (1.5.0)
# Collecting h11>=0.8 (from uvicorn==0.23.1)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx==0.24.0) (4.9.0)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.8.4) (0.3.1)
# Using cached fastapi-0.95.2-py3-none-any.whl (56 kB)
# Using cached httpx-0.24.0-py3-none-any.whl (75 kB)
# Using cached pydantic-1.10.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Using cached uvicorn-0.23.1-py3-none-any.whl (59 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Using cached httpcore-0.17.3-py3-none-any.whl (74 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Installing collected packages: requests, pydantic, h11, click, uvicorn, starlette, httpcore, httpx, fastapi
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.5
#     Uninstalling pydantic-2.11.5:
#       Successfully uninstalled pydantic-2.11.5
#   Attempting uninstall: h11
#     Found existing installation: h11 0.16.0
#     Uninstalling h11-0.16.0:
#       Successfully uninstalled h11-0.16.0
#   Attempting uninstall: click
#     Found existing installation: click 8.2.1
#     Uninstalling click-8.2.1:
#       Successfully uninstalled click-8.2.1
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.34.2
#     Uninstalling uvicorn-0.34.2:
#       Successfully uninstalled uvicorn-0.34.2
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.46.2
#     Uninstalling starlette-0.46.2:
#       Successfully uninstalled starlette-0.46.2
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.9
#     Uninstalling httpcore-1.0.9:
#       Successfully uninstalled httpcore-1.0.9
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.115.12
#     Uninstalling fastapi-0.115.12:
#       Successfully uninstalled fastapi-0.115.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rich-toolkit 0.14.6 requires click>=8.1.7, but you have click 8.1.3 which is incompatible.
# sse-starlette 2.3.5 requires starlette>=0.41.3, but you have starlette 0.27.0 which is incompatible.
# acp-sdk 0.8.4 requires fastapi[standard]>=0.115.8, but you have fastapi 0.95.2 which is incompatible.
# acp-sdk 0.8.4 requires httpx>=0.26.0, but you have httpx 0.24.0 which is incompatible.
# acp-sdk 0.8.4 requires pydantic>=2.11.1, but you have pydantic 1.10.7 which is incompatible.
# beeai-framework-starter 0.0.1 requires pydantic<3.0,>=2.10, but you have pydantic 1.10.7 which is incompatible.
# beeai-framework 0.1.21 requires pydantic<3.0,>=2.10, but you have pydantic 1.10.7 which is incompatible.
# beeai-framework 0.1.21 requires requests<3.0,>=2.32, but you have requests 2.31.0 which is incompatible.
# qiskit-ibm-runtime 0.39.0 requires pydantic>=2.5.0, but you have pydantic 1.10.7 which is incompatible.
# duckduckgo-search 8.0.2 requires click>=8.1.8, but you have click 8.1.3 which is incompatible.
# litellm 1.70.4 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.7 which is incompatible.
# mcp 1.9.1 requires httpx>=0.27, but you have httpx 0.24.0 which is incompatible.
# mcp 1.9.1 requires pydantic<3.0.0,>=2.7.2, but you have pydantic 1.10.7 which is incompatible.
# pydantic-settings 2.9.1 requires pydantic>=2.7.0, but you have pydantic 1.10.7 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.31.0 which is incompatible.
# langchain 0.3.25 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.7 which is incompatible.
# google-genai 1.15.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.24.0 which is incompatible.
# google-genai 1.15.0 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.7 which is incompatible.
# thinc 8.3.6 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.7 which is incompatible.
# albumentations 2.0.6 requires pydantic>=2.9.2, but you have pydantic 1.10.7 which is incompatible.
# langchain-core 0.3.59 requires pydantic<3.0.0,>=2.5.2; python_full_version < "3.12.4", but you have pydantic 1.10.7 which is incompatible.
# Successfully installed click-8.1.3 fastapi-0.95.2 h11-0.14.0 httpcore-0.17.3 httpx-0.24.0 pydantic-1.10.7 requests-2.31.0 starlette-0.27.0 uvicorn-0.23.1

# %%
# !pip install beeai openai qiskit python-dotenv
# Out:
# Requirement already satisfied: beeai in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.78.1)
# Requirement already satisfied: qiskit in /usr/local/lib/python3.11/dist-packages (2.0.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from beeai) (2.31.0)
# Requirement already satisfied: python-socketio in /usr/local/lib/python3.11/dist-packages (from beeai) (5.13.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from beeai) (1.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.24.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.10.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from qiskit) (0.16.0)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.11/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from qiskit) (1.15.3)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.11/dist-packages (from qiskit) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from qiskit) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.11/dist-packages (from qiskit) (0.13.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (0.17.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from stevedore>=3.0.0->qiskit) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->qiskit) (1.3.0)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio->beeai) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio->beeai) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->beeai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->beeai) (2.4.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit) (75.2.0)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from python-engineio>=4.11.0->python-socketio->beeai) (1.1.0)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.11/dist-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio->beeai) (1.2.0)

# %%
import os
from dotenv import load_dotenv

os.environ["IBM_QUANTUM_API_TOKEN"] = "055baaee60c6de48e5f32103bcc6da835d5235529d7c964b8825a30f3c64461ab09a1ca32e642a7acbb01c7cdbea288f4435daac3676841308953097de48bdf7"

# Save it in a .env file (optional but good practice)
with open(".env", "w") as f:
    f.write(f"IBM_QUANTUM_API_TOKEN={os.environ['IBM_QUANTUM_API_TOKEN']}")

# Load environment variables
load_dotenv()

print("Loaded IBM Quantum API Token:", os.getenv("IBM_QUANTUM_API_TOKEN")[:10], "...")
# Out:
# Loaded IBM Quantum API Token: 055baaee60 ...

# %%
# !pip install qiskit-ibm-runtime
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in /usr/local/lib/python3.11/dist-packages (0.39.0)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (2.0.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (0.66.0)
# Collecting pydantic>=2.5.0 (from qiskit-ibm-runtime)
#   Using cached pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: qiskit>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qiskit-ibm-runtime) (24.2)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.22.1 in /usr/local/lib/python3.11/dist-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.5.0->qiskit-ibm-runtime) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (1.15.3)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (1.13.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (5.4.1)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.11/dist-packages (from qiskit>=1.4.1->qiskit-ibm-runtime) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19->qiskit-ibm-runtime) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19->qiskit-ibm-runtime) (2025.4.26)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.11/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (43.0.3)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.11.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.17.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.22.1->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: pbr>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from stevedore>=3.0.0->qiskit>=1.4.1->qiskit-ibm-runtime) (6.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->qiskit>=1.4.1->qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.22)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=1.4.1->qiskit-ibm-runtime) (75.2.0)
# Using cached pydantic-2.11.5-py3-none-any.whl (444 kB)
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.7
#     Uninstalling pydantic-1.10.7:
#       Successfully uninstalled pydantic-1.10.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# acp-sdk 0.8.4 requires fastapi[standard]>=0.115.8, but you have fastapi 0.95.2 which is incompatible.
# acp-sdk 0.8.4 requires httpx>=0.26.0, but you have httpx 0.24.0 which is incompatible.
# beeai-framework 0.1.21 requires requests<3.0,>=2.32, but you have requests 2.31.0 which is incompatible.
# mcp 1.9.1 requires httpx>=0.27, but you have httpx 0.24.0 which is incompatible.
# fastapi 0.95.2 requires pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2, but you have pydantic 2.11.5 which is incompatible.
# google-genai 1.15.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.24.0 which is incompatible.
# Successfully installed pydantic-2.11.5

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Load IBM Quantum API token
api_token = os.getenv("IBM_QUANTUM_API_TOKEN")

# Initialize the service
service = QiskitRuntimeService(channel="ibm_quantum", token=api_token)

# List available backends
backends = service.backends()
print("Available IBM Quantum backends:")
for backend in backends:
    print("-", backend.name)
# Out:
# <ipython-input-8-697957831de0>:7: DeprecationWarning: The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. After this date, "ibm_cloud" and "local" will be the only valid channels. For information on migrating to the new IBM Quantum Platform on the "ibm_cloud" channel, review the migration guide https://quantum.cloud.ibm.com/docs/migration-guides/classic-iqp-to-cloud-iqp .
#   service = QiskitRuntimeService(channel="ibm_quantum", token=api_token)
# Available IBM Quantum backends:
# - ibm_brisbane
# - ibm_sherbrooke

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# Model ID
model_id = "deepseek-ai/deepseek-llm-7b-chat"

# Tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_id)

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    offload_folder="/content/drive/MyDrive/quantum_tutor_offload",
    torch_dtype="auto"
)
# Create generation pipeline
deepseek_llm = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu and disk.
# Device set to use cpu

# %%
# !git clone https://github.com/i-am-bee/beeai-platform-agent-starter.git
# !git clone https://github.com/i-am-bee/beeai-framework-py-starter.git
# Out:
# Cloning into 'beeai-platform-agent-starter'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 114 (delta 31), reused 14 (delta 13), pack-reused 60 (from 1)
# Receiving objects: 100% (114/114), 102.79 KiB | 1.27 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Cloning into 'beeai-framework-py-starter'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 115 (delta 32), reused 22 (delta 14), pack-reused 63 (from 1)
# Receiving objects: 100% (115/115), 316.33 KiB | 2.73 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
# Create project folder in Drive
# !mkdir -p /content/drive/MyDrive/quantum_tutor_project

# Move repos into it
# !mv beeai-platform-agent-starter /content/drive/MyDrive/quantum_tutor_project/
# !mv beeai-framework-py-starter /content/drive/MyDrive/quantum_tutor_project/
# Out:
# mv: cannot move 'beeai-framework-py-starter' to '/content/drive/MyDrive/quantum_tutor_project/beeai-framework-py-starter': Directory not empty

# %%
# Paths
agent_dir = "/content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter/agents/quantum_tutor_agent"

# Create the agent folder
# !mkdir -p $agent_dir

# Create __init__.py with placeholder class
with open(f"{agent_dir}/__init__.py", "w") as f:
    f.write("""
from beeai.agent import Agent

class QuantumTutorAgent(Agent):
    def run(self, message: str, **kwargs):
        return {"response": f"QuantumTutor received: {message}"}
""")

# Create config.yaml
with open(f"{agent_dir}/config.yaml", "w") as f:
    f.write("""
id: quantum_tutor_agent
class_name: QuantumTutorAgent
module: agents.quantum_tutor_agent
description: Agent that helps users learn Quantum Computing using IBM Qiskit and LLMs.
""")

# %%
# Go to the framework starter repo folder
# %cd /content/drive/MyDrive/quantum_tutor_project/beeai-framework-py-starter

# Install the framework package locally in editable mode
# !pip install -e .
# Out:
# /content/drive/MyDrive/quantum_tutor_project/beeai-framework-py-starter
# Obtaining file:///content/drive/MyDrive/quantum_tutor_project/beeai-framework-py-starter
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: beeai-framework==0.1.21 in /usr/local/lib/python3.11/dist-packages (from beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.1.21)
# Requirement already satisfied: openinference-instrumentation-beeai<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from beeai-framework-starter==0.0.1) (0.1.6)
# Requirement already satisfied: opentelemetry-exporter-otlp<2.0.0,>=1.32.1 in /usr/local/lib/python3.11/dist-packages (from beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.32.1 in /usr/local/lib/python3.11/dist-packages (from beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: pydantic<3.0,>=2.10 in /usr/local/lib/python3.11/dist-packages (from beeai-framework-starter==0.0.1) (2.11.5)
# Requirement already satisfied: termcolor<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from beeai-framework-starter==0.0.1) (2.5.0)
# Requirement already satisfied: aiofiles<25.0.0,>=24.1.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (24.1.0)
# Requirement already satisfied: cachetools<6.0.0,>=5.5.2 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (5.5.2)
# Requirement already satisfied: chevron<0.15.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.14.0)
# Requirement already satisfied: json-repair<0.40.0,>=0.39.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.39.1)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.1.0)
# Requirement already satisfied: litellm<2.0.0,>=1.60.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.70.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.9.1)
# Requirement already satisfied: requests<3.0,>=2.32 in /usr/local/lib/python3.11/dist-packages (from beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.32.3)
# Requirement already satisfied: acp-sdk<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.8.4)
# Requirement already satisfied: duckduckgo-search<9.0.0,>=8.0.2 in /usr/local/lib/python3.11/dist-packages (from beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (8.0.2)
# Requirement already satisfied: mcp<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.9.1)
# Requirement already satisfied: uvicorn<0.35.0,>=0.34.2 in /usr/local/lib/python3.11/dist-packages (from beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.34.2)
# Requirement already satisfied: wikipedia-api<0.9.0,>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.8.1)
# Requirement already satisfied: openinference-instrumentation>=0.1.27 in /usr/local/lib/python3.11/dist-packages (from openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (0.1.31)
# Requirement already satisfied: openinference-semantic-conventions>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (0.1.17)
# Requirement already satisfied: opentelemetry-api>=1.31.1 in /usr/local/lib/python3.11/dist-packages (from openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.52b1 in /usr/local/lib/python3.11/dist-packages (from openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.52b1 in /usr/local/lib/python3.11/dist-packages (from openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (0.54b1)
# Requirement already satisfied: wrapt>=1.17.2 in /usr/local/lib/python3.11/dist-packages (from openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (1.17.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (1.33.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-proto==1.33.1->opentelemetry-exporter-otlp-proto-grpc==1.33.1->opentelemetry-exporter-otlp<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (5.29.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<2.0.0,>=1.32.1->beeai-framework-starter==0.0.1) (4.13.2)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.31.1->openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (8.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=2.10->beeai-framework-starter==0.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=2.10->beeai-framework-starter==0.0.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=2.10->beeai-framework-starter==0.0.1) (0.4.0)
# Requirement already satisfied: fastapi>=0.115.8 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.115.12)
# Requirement already satisfied: httpx-sse>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.4.0)
# Requirement already satisfied: httpx>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.28.1)
# Requirement already satisfied: janus>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.0.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.52b1 in /usr/local/lib/python3.11/dist-packages (from acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-httpx>=0.52b1 in /usr/local/lib/python3.11/dist-packages (from acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.54b1)
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search<9.0.0,>=8.0.2->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (8.2.1)
# Requirement already satisfied: primp>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search<9.0.0,>=8.0.2->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from duckduckgo-search<9.0.0,>=8.0.2->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (5.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.8.4)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (4.23.0)
# Requirement already satisfied: openai>=1.68.2 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.78.1)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.0.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.9.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.21.1)
# Requirement already satisfied: anyio>=4.5 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.2.0->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (4.9.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.2.0->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.2.0->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.3.5)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.11/dist-packages (from mcp<2.0.0,>=1.2.0->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.46.2)
# Requirement already satisfied: packaging>=18.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation>=0.52b1->openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.32->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.32->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.32->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.32->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<0.35.0,>=0.34.2->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=4.5->mcp<2.0.0,>=1.2.0->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.3.1)
# Requirement already satisfied: fastapi-cli>=0.0.5 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.0.7)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.2.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.26.0->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.31.1->openinference-instrumentation-beeai<0.2.0,>=0.1.6->beeai-framework-starter==0.0.1) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.24.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.9.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.68.2->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (4.67.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.52b1->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.52b1->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.52b1->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.8.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.7.0->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2024.11.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (6.4.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.20.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.6.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.31.2)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.15.3)
# Requirement already satisfied: rich-toolkit>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.14.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (6.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (15.0.1)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.0->aiohttp->litellm<2.0.0,>=1.60.0->beeai-framework==0.1.21->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.3.1)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.11/dist-packages (from rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.11.1->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]>=0.115.8->acp-sdk<0.9.0,>=0.8.4->beeai-framework[acp,beeai-platform,duckduckgo,mcp,wikipedia]==0.1.21->beeai-framework-starter==0.0.1) (0.1.2)
# Building wheels for collected packages: beeai-framework-starter
#   Building editable for beeai-framework-starter (pyproject.toml) ... done
#   Created wheel for beeai-framework-starter: filename=beeai_framework_starter-0.0.1-py3-none-any.whl size=7889 sha256=5cad0c6e0d5609cfc66a63be02809d8b1b65bcbdef8e3e36bb8f4a068d1bba6b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wbn7ho4k/wheels/91/98/a8/6e6b3b7767b198acda75449e7ea6517817941ac1693038498a
# Successfully built beeai-framework-starter
# Installing collected packages: beeai-framework-starter
#   Attempting uninstall: beeai-framework-starter
#     Found existing installation: beeai-framework-starter 0.0.1
#     Uninstalling beeai-framework-starter-0.0.1:
#       Successfully uninstalled beeai-framework-starter-0.0.1
# Successfully installed beeai-framework-starter-0.0.1

# %%
class Agent:
    def run(self, message: str, **kwargs):
        raise NotImplementedError

class QuantumTutorAgent(Agent):
    def run(self, message: str, **kwargs):
        return {"response": f"QuantumTutor received: {message}"}

# %%
code = """
class Agent:
    def run(self, message: str, **kwargs):
        raise NotImplementedError

class QuantumTutorAgent(Agent):
    def run(self, message: str, **kwargs):
        return {'response': f'QuantumTutor received: {message}'}
"""

file_path = '/content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter/agents/quantum_tutor_agent/__init__.py'

with open(file_path, 'w') as f:
    f.write(code)

print(f"Updated {file_path} successfully.")
# Out:
# Updated /content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter/agents/quantum_tutor_agent/__init__.py successfully.

# %%
import sys
sys.path.append('/content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter')

from agents.quantum_tutor_agent import QuantumTutorAgent

agent = QuantumTutorAgent()
response = agent.run("Hello Quantum Tutor!")
print(response['response'])
# Out:
# QuantumTutor received: Hello Quantum Tutor!

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "deepseek-ai/deepseek-llm-7b-chat"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    offload_folder="/content/drive/MyDrive/quantum_tutor_offload",
    torch_dtype="auto"
)

deepseek_llm = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu and disk.
# Device set to use cpu

# %%
# Save this into your __init__.py file for QuantumTutorAgent

class Agent:
    def run(self, message: str, **kwargs):
        raise NotImplementedError

class QuantumTutorAgent(Agent):
    def __init__(self, llm_pipeline):
        self.llm = llm_pipeline

    def run(self, message: str, **kwargs):
        # Generate response from the deepseek LLM pipeline
        generated = self.llm(message, max_new_tokens=100, do_sample=True)
        response_text = generated[0]['generated_text']
        return {'response': response_text}

# %%
code = '''
class Agent:
    def run(self, message: str, **kwargs):
        raise NotImplementedError

class QuantumTutorAgent(Agent):
    def __init__(self, llm_pipeline):
        self.llm = llm_pipeline

    def run(self, message: str, **kwargs):
        generated = self.llm(message, max_new_tokens=100, do_sample=True)
        response_text = generated[0]['generated_text']
        return {'response': response_text}
'''

file_path = '/content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter/agents/quantum_tutor_agent/__init__.py'

with open(file_path, 'w') as f:
    f.write(code)

print(f"QuantumTutorAgent updated at {file_path}")
# Out:
# QuantumTutorAgent updated at /content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter/agents/quantum_tutor_agent/__init__.py

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Add your project folder to sys.path
import sys
sys.path.append('/content/drive/MyDrive/quantum_tutor_project/beeai-platform-agent-starter')

# Import transformers and load Deepseek model
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

model_id = "deepseek-ai/deepseek-llm-7b-chat"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    offload_folder="/content/drive/MyDrive/quantum_tutor_offload",
    torch_dtype="auto"
)

deepseek_llm = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Import your agent class
from agents.quantum_tutor_agent import QuantumTutorAgent

# Initialize agent with model pipeline
agent = QuantumTutorAgent(deepseek_llm)

print("Setup complete! You can now run your agent.")
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/594 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/22.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.97G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.6k [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.85G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Device set to use cuda:0
# Setup complete! You can now run your agent.

# %%
import sys
import importlib

# Remove old module if already loaded
if 'agents.quantum_tutor_agent' in sys.modules:
    importlib.reload(sys.modules['agents.quantum_tutor_agent'])

from agents.quantum_tutor_agent import QuantumTutorAgent

agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("Explain superposition in quantum computing.")
print(response['response'])
# Out:
# Explain superposition in quantum computing. Theoretical computer science.
#
# Superposition is a fundamental concept in quantum computing that allows quantum bits (qubits) to represent a state that is both 0 and 1 simultaneously. In classical computing, bits can only represent a single state, either 0 or 1.
#
# In superposition, a qubit can be in a state where it represents both 0 and 1 at the same time. This means that the qubit can perform multiple calculations simultaneously, which is a significant advantage over classical

# %%
agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("What is Quantum Computing?")
print(response['response'])
# Out:
# What is Quantum Computing?
# Quantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data. Unlike classical computers, which use binary digits (bits) that can have a value of either 0 or 1, quantum computers use quantum bits (qubits) that can exist in multiple states at once. This allows quantum computers to perform certain types of calculations much faster than classical computers.
# Quantum computing is still a relatively new and developing field, and there are

# %%
agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("If I had to learn about Quantum Computing from basic to advanced,what are the things that need to be done as abeginner for me to grasp all concepts fast?")
print(response['response'])
# Out:
# If I had to learn about Quantum Computing from basic to advanced,what are the things that need to be done as abeginner for me to grasp all concepts fast?
# I would recommend the following steps:
#
# 1. **Understand Basic Concepts of Quantum Computing**: Start with understanding the basic concepts of quantum computing such as superposition, entanglement, quantum bits (qubits), quantum gates, quantum algorithms, etc.
#
# 2. **Learn Quantum Programming**: Start learning a quantum programming language like Q# (Microsoft's quantum programming language) or Qiskit (IBM's quantum programming language). This will help you understand the syntax and structures used in quantum

# %%
agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("what is quantum")
print(response['response'])
# Out:
# what is quantum computing?
# Quantum computing is a new way of processing information that uses quantum bits, or qubits, to perform computations. Unlike traditional computing, which uses binary bits (0s and 1s) to store and process information, quantum computing uses qubits, which can exist in multiple states at once. This allows quantum computers to perform certain types of calculations much faster than traditional computers.
# The potential applications of quantum computing are vast and include areas such as cryptography, drug discovery, and optimization problems.

# %%
agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("draw basic quantum ckt for quantum computing")
print(response['response'])
# Out:
# draw basic quantum ckt for quantum computing, and show how it is different from classical computing
# Quantum Computing is a field of computing that utilizes quantum bits or qubits, instead of classical bits, to perform computations.
# A basic quantum circuit for quantum computing is shown below:
#
# ```
# X(0) --> CNOT(0, 1) --> X(1) --> H(2) --> CNOT(2, 3) --> X(3) --> H(4) -->...
# ```
#
# In this

# %%
agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("If were to do research in Quantum Computing which topic would be relevant to today's time")
print(response['response'])
# Out:
# If were to do research in Quantum Computing which topic would be relevant to today's time?
# Cryptography or quantum teleportation or some other topic?
# Quantum cryptography is one of the most promising areas of quantum computing research. With the increasing amount of data being shared and stored online, the need for secure communication has become more important than ever. Quantum cryptography uses the principles of quantum mechanics to provide a level of security that is impossible to break with classical computers.
# Quantum teleportation is another exciting area of research, but it is still in the early stages and not as practical

# %%
agent = QuantumTutorAgent(deepseek_llm)
response = agent.run("Suggest me resource material to learn this topic (in english)")
print(response['response'])
# Out:
# Suggest me resource material to learn this topic (in english)
# Thank you!
# I am glad to provide you with some resources to learn more about the topic of deep learning and reinforcement learning, which are two important areas of machine learning:
#
# 1. Deep Learning:
#
#    a. Books:
#        1. "Deep Learning" by Ian Goodfellow, Yoshua Bengio, and Aaron Courville.
#        2. "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow" by Aurélien
